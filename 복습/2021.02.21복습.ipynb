# %%
import pandas as pd
import FinanceDataReader as fdr

# %%
df_krx = fdr.StockListing("KRX")

# %%
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 이현우         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도

# %%
df_krx.shape
# Out:
# (7308, 10)

# %%
df_krx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7308 entries, 0 to 7307
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          7308 non-null   object
#  1   Market          7308 non-null   object
#  2   Name            7308 non-null   object
#  3   Sector          2421 non-null   object
#  4   Industry        2402 non-null   object
#  5   ListingDate     2421 non-null   datetime64[ns]
#  6   SettleMonth     2421 non-null   object
#  7   Representative  2421 non-null   object
#  8   HomePage        2245 non-null   object
#  9   Region          2421 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 628.0+ KB

# %%
df_krx.describe()
# Out:
#         Symbol Market   Name         Sector Industry          ListingDate  \
# count     7308   7308   7308           2421     2402                 2421
# unique    7308      3   7308            158     2250                 1784
# top     52FG23  KOSPI  인바이오젠  특수 목적용 기계 제조업   기업인수합병  1976-06-30 00:00:00
# freq         1   5664      1            142       37                    8
# first      NaN    NaN    NaN            NaN      NaN  1956-03-03 00:00:00
# last       NaN    NaN    NaN            NaN      NaN  2021-02-16 00:00:00
#
#        SettleMonth Representative                   HomePage Region
# count         2421           2421                       2245   2421
# unique           9           2307                       2224     22
# top            12월              -  http://www.taegugas.co.kr  서울특별시
# freq          2360              5                          2    977
# first          NaN            NaN                        NaN    NaN
# ...

# %%
# df_krx.to_csv("krx.csv", index=False)

# %%
# pd.read_csv("krx.csv")

# %%
df = fdr.DataReader('005930','2017','2021')
df.head()
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2017-01-02  35980  36240  35880  36100   93012  0.001665
# 2017-01-03  36280  36620  36020  36480  147153  0.010526
# 2017-01-04  36500  36520  36100  36160  159435 -0.008772
# 2017-01-05  36060  36060  35540  35560  219349 -0.016593
# 2017-01-06  36180  36440  36040  36200  177619  0.017998

# %%
df['Close'].plot()

# %%
df_krx = pd.read_csv("krx.csv")
df_krx.shape
# Out:
# (6537, 10)

# %%
df_krx.head(3)
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
#
#   SettleMonth      Representative                       HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 이현우         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시

# %%
df_krx[['Symbol','Name']].head()
# Out:
#    Symbol    Name
# 0  060310      3S
# 1  095570  AJ네트웍스
# 2  006840   AK홀딩스
# 3  054620  APS홀딩스
# 4  265520   AP시스템

# %%
df_krx.loc[df_krx['Name'] == '희림', 'Symbol']
# Out:
# 6535    037440
# Name: Symbol, dtype: object

# %%
# df_krx의 Name column 에서 '빅히트'에 해당하는 row를 전부 가져오는데 Name column만 가져와
# list 형태로 index 번호는 빼고 ['빅히트'] 만 가져오게 되고 [0]을 통해 list에 있는 string만 가져오게 됩니다.
# 빅히트 (series) -> ['빅히트'] (list) -> '빅히트' (string)
item_name = "빅히트"
df_krx.loc[df_krx['Name'] == item_name, 'Symbol'].tolist()[0]
# Out:
# '352820'

# %%
def item_code_by_item_name(item_name):
    """
    종목명을 받아 종목코드를 찾아 반환하는 함수
    """
    item_code_list = df_krx.loc[df_krx['Name'] == item_name, 'Symbol'].tolist()
    if len(item_code_list) > 0:
        item_code = item_code_list[0]
        return item_code
    else:
        return False

# %%
item_code_by_item_name("삼성전자")
# Out:
# '005930'

# %%
def find_item_list(item_name,year=2020):
    """
    종목명을 넘겨주면 일별시세를 반화하는 함수
    내부에서 종목명으로 종목코드를 반환하는 함수(item_code_by_name)로
    종목의 시세를 수집
    """
    item_code = item_code_by_item_name(item_name)
    if item_code:
        df_day = fdr.DataReader(item_code, str(year))
        return df_day
    else:
        return False

# %%
find_item_list("삼성전자",2021)
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-04  81000  84400  80200  83000  38655276  0.024691
# 2021-01-05  81600  83900  81600  83900  35335669  0.010843
# 2021-01-06  83300  84500  82100  82200  42089013 -0.020262
# 2021-01-07  82800  84200  82700  82900  32644642  0.008516
# 2021-01-08  83300  90000  83000  88800  59013307  0.071170
# 2021-01-11  90000  96800  89500  91000  90306177  0.024775
# 2021-01-12  90300  91400  87800  90600  48682416 -0.004396
# 2021-01-13  89800  91200  89100  89700  36068848 -0.009934
# 2021-01-14  88700  90000  88700  89700  26393970  0.000000
# 2021-01-15  89800  91800  88000  88000  33431809 -0.018952
# 2021-01-18  86600  87300  84100  85000  43227951 -0.034091
# 2021-01-19  84500  88000  83600  87000  39895044  0.023529
# 2021-01-20  89000  89000  86500  87200  25211127  0.002299
# 2021-01-21  87500  88600  86500  88100  25318011  0.010321
# 2021-01-22  89000  89700  86800  86800  30861661 -0.014756
# ...
