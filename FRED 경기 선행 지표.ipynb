# %% [markdown]
# https://github.com/FinanceData/FinanceDataReader/blob/master/tutorial/FinanceDataReader%20Tutorial%20-%20FRED%20%EA%B2%BD%EA%B8%B0%20%EC%84%A0%ED%96%89%20%EC%A7%80%ED%91%9C.ipynb

# %%
#matplotlib 설정
import matplotlib.pyplot as plt

plt.rcParams['axes.grid'] = True
plt.rcParams['figure.figsize'] = (14,7)
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['axes.formatter.limits'] = -10000,10000

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('NASDAQCOM', data_source='fred')
df
# Out:
#             NASDAQCOM
# DATE
# 1971-02-05     100.00
# 1971-02-08     100.84
# 1971-02-09     100.76
# 1971-02-10     100.69
# 1971-02-11     101.45
# ...               ...
# 2021-02-08   13987.64
# 2021-02-09   14007.70
# 2021-02-10   13972.53
# 2021-02-11   14025.77
# 2021-02-12   14095.47
#
# [13051 rows x 1 columns]

# %%
df.plot()

# %%
ax=df['2020':].plot()
ax = ax.axvspan('2020-09-01', '2020-10-01',color='orange',alpha=0.2)

# %% [markdown]
# 선행지표란 경기가 좋아질 것인지 혹은 나빠질것인지 앞서 반응하는 지표를 말한다.
# 대표적인 선행지표들이 무엇이 있는지 그리고, 이 선행지표들을 살펴봄으로
# 향후 주식 시장의 흐름을 가늠해 볼수있다.

# %% [markdown]
# # 주간 실업수당 청구 건수

# %%
#2008년 금융위기 나스닥지수와 주간 살업수당 청구건수

df=fdr.DataReader(['NASDAQCOM','ICSA'], start='2006',end='2010',data_source='fred')
ax=df.plot(secondary_y='NASDAQCOM')
ax=ax.axvspan('2007-12-01','2009-03-30',color='gray',alpha=0.2)

# %%
#최근(2020년 10월), 나스닥지수와 주간실업수당 청구건수
df=fdr.DataReader(['NASDAQCOM','ICSA'],start='2019',data_source='fred')
ax=df.plot(secondary_y='NASDAQCOM')

# %%
df.tail()
# Out:
#             NASDAQCOM      ICSA
# DATE
# 2021-02-08   13987.64  793000.0
# 2021-02-09   14007.70  793000.0
# 2021-02-10   13972.53  793000.0
# 2021-02-11   14025.77  793000.0
# 2021-02-12   14095.47  793000.0

# %% [markdown]
# # 소비자심리지수(UMCSENT)

# %%
df=fdr.DataReader(['NASDAQCOM','UMCSENT'],start='2006',end='2010',data_source='fred')
ax=df.plot(secondary_y='NASDAQCOM')
ax=ax.axvspan('2007-12-01','2009-03-30',color='gray',alpha=0.2)

# %%
df=fdr.DataReader(['NASDAQCOM','UMCSENT'],'2019',data_source='fred')
ax=df.plot(secondary_y='NASDAQCOM')

# %%
df.tail()
# Out:
#             NASDAQCOM  UMCSENT
# DATE
# 2021-02-08   13987.64     80.7
# 2021-02-09   14007.70     80.7
# 2021-02-10   13972.53     80.7
# 2021-02-11   14025.77     80.7
# 2021-02-12   14095.47     80.7

# %% [markdown]
# # 주택 판매 지수 (HSN1F)

# %%
df=fdr.DataReader(['NASDAQCOM','HSN1F'],'2005','2011',data_source='fred')
ax=df.plot(secondary_y='NASDAQCOM')
ax=ax.axvspan('2007-12-01','2009-03-30',color='gray',alpha=0.2)

# %%
df=fdr.DataReader(['NASDAQCOM','HSN1F'],'2019',data_source='fred')
ax=df.plot(secondary_y='NASDAQCOM')

# %% [markdown]
# # 실업률(UNRATE)

# %%
df = fdr.DataReader(['NASDAQCOM', 'UNRATE'], start='2005', end='2011', data_source='fred')
ax = df.plot(secondary_y='NASDAQCOM')
ax = ax.axvspan('2007-12-01', '2009-03-30', color='gray', alpha=0.2)

# %%
df=fdr.DataReader(['NASDAQCOM','UNRATE'],'2019',data_source='fred')
ax=df.plot(secondary_y='NASDAQCOM')

# %% [markdown]
# # M2 통화량

# %%
df=fdr.DataReader(['NASDAQCOM','M2'],'2005','2011',data_source='fred')
ax=df.plot(secondary_y='NASDAQCOM')
ax=ax.axvspan('2007-12-01','2009-03-30',color='gray',alpha=0.2)

# %%
df=fdr.DataReader(['NASDAQCOM','M2'],'2019',data_source='fred')
ax=df.plot(secondary_y='NASDAQCOM')

# %% [markdown]
# # 하이일드 채권 스프레드

# %%
df=fdr.DataReader(['NASDAQCOM', 'BAMLH0A0HYM2'],'2005','2011',data_source='fred')
ax=df.plot(secondary_y='NASDAQCOM')
ax=ax.axvspan('2007-12-01','2009-03-30',color='gray',alpha=0.2)

# %%
df=fdr.DataReader(['NASDAQCOM','BAMLH0A0HYM2'],'2019',data_source='fred')
ax=df.plot(secondary_y='NASDAQCOM')
