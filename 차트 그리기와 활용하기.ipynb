# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\programdata\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: packaging>=16.8 in c:\programdata\anaconda3\lib\site-packages (from bokeh) (20.4)
# Requirement already satisfied: numpy>=1.11.3 in c:\programdata\anaconda3\lib\site-packages (from bokeh) (1.18.5)
# Requirement already satisfied: tornado>=5.1 in c:\programdata\anaconda3\lib\site-packages (from bokeh) (6.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\programdata\anaconda3\lib\site-packages (from bokeh) (3.7.4.2)
# Requirement already satisfied: PyYAML>=3.10 in c:\programdata\anaconda3\lib\site-packages (from bokeh) (5.3.1)
# Requirement already satisfied: Jinja2>=2.7 in c:\programdata\anaconda3\lib\site-packages (from bokeh) (2.11.2)
# Requirement already satisfied: pillow>=4.0 in c:\programdata\anaconda3\lib\site-packages (from bokeh) (7.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\programdata\anaconda3\lib\site-packages (from bokeh) (2.8.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=16.8->bokeh) (2.4.7)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from packaging>=16.8->bokeh) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.7->bokeh) (1.1.1)

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('005930','2021-01-01','2021-02-15')
fdr.chart.plot(df)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ac973bf9-919f-4a6f-ad2c-c9e67068efe1" data-root-id="1156"></div>

# %%
#fdr.chart.plot()파라미터
fdr.chart.plot(df,title='삼성전자(005930)')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1367">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2d477e5c-41bf-4026-abfc-59e1f594b556" data-root-id="1522"></div>

# %%
fdr.chart.config(title='삼성전자(005930) 2021년')
fdr.chart.config(width=400,height=200)
fdr.chart.config(volume=False)

fdr.chart.plot(df)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1763">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b961ce9a-e958-4ae2-9649-2b32624449d6" data-root-id="1865"></div>

# %%
config = {'title': 'fdr.chart.config()를 사용하여 설정을 한번에 지정',
          'width': 600,
          'height': 300,
          'volume': True,
 }
fdr.chart.config(config=config)

# %%
fdr.chart.plot(df)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2066">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1f3f197a-b388-4311-8291-93ecdcb5305f" data-root-id="2221"></div>

# %%
fdr.chart.config(reset=True)
df = fdr.DataReader('000660','2021')

fdr.chart.plot(df)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2512">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5d7cdd0b-b605-49f2-bf94-3bd1f213ed55" data-root-id="2667"></div>
